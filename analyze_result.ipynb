# %%
import soundfile as sf
import numpy as np
import matplotlib.pyplot as plt
y1,sr1 = sf.read('data\RIRs\s1_p01_m1.wav')
y2,sr2 = sf.read('data\RIRs\s1_p01i_m1.wav')
y3,sr3 = sf.read('data\RIRs\s1_p01r_m1.wav')
time1 = np.arange(0, len(y1)) / sr1
time2 = np.arange(0, len(y2)) / sr2
time3 = np.arange(0, len(y3)) / sr3
# plt.plot(time1, y1)
# plt.plot(time2, y2)
plt.plot(time3, y3)
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.legend(['RIR at position1', 'interpolated RIR early part at the middle of position1 and position2'])
plt.title('Compare the RIR and interpolated RIR')
# plt.plot(time3, y3)
# plt.xlim(0, 0.5)
# Out:
# Text(0.5, 1.0, 'Compare the RIR and interpolated RIR')

# %%
import soundfile as sf
import numpy as np
import matplotlib.pyplot as plt
y1,sr1 = sf.read('data\RIRs\s2_p03_m1.wav')
y2,sr2 = sf.read('data\RIRs\s2_p03t_m1.wav')
y3,sr3 = sf.read('data\RIRs\s2_p01t_m1.wav')
time1 = np.arange(0, len(y1)) / sr1
time2 = np.arange(0, len(y2)) / sr2
time3 = np.arange(0, len(y3)) / sr3
plt.plot(time1, y1)
plt.plot(time2, y2)
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.legend(['RIR at position3', 'interpolated RIR early part at position3'])
plt.title('Compare the RIR and interpolated RIR')
# plt.plot(time3, y3)
plt.xlim(0, 0.5)
# Out:
# (0.0, 0.5)
